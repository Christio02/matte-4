# %% [markdown]
# ## Bisection method

# %%
def f(x):
    return (2 - 2* 3**x)*x**2 + 4*(2*x - 2)*3**x + 4*(2 - 2*x)

def bisection_method(f, a, b):
    a_0, b_0 = a, b
    error_bound = (b_0 - a_0) / 2
    num_iter = 0
    while error_bound > 1e-4:
        c_k = (a_0 + b_0) / 2

        if f(c_k) == 0 or error_bound <= 1e-4:
            return c_k
        else:
            if f(a_0)*f(c_k) < 0:
                b_0 = c_k
                
            else:
                a_0= c_k
                
        error_bound = (b_0 - a_0) / 2
        num_iter += 1

    return c_k, num_iter


c_k, num_iter = bisection_method(f, -2, 3)
print(f"Root: {c_k} \n Number of iterations: {num_iter} ")
# Out:
# Root: -3.0517578125e-05
#  Number of iterations: 15

# %% [markdown]
# ## Newton's method

# %%
import numpy as np

def f(x):
    return x - np.e ** -x

def f_derivative(x):
    return 1 + np.e ** -x


def newton_method(f, f_der, x0, error_bound):
    x = x0
    current_error = f(x)
    while current_error
# Out:
# Hello world
# 1.8646647167633872
